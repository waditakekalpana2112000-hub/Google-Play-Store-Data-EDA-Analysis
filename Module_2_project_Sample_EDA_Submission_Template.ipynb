# %% [markdown]
# # **Project Name**    -**Google Play Store App Review(Complete EDA analysis)**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Google Play Store is one of the largest app platforms, offering millions of apps in different categories such as Games, Education, Business, Health, Finance, and Lifestyle. Many factors like ratings, reviews, installs, price, and app updates influence an app's success.
#
# This project is based on a dataset containing 122,662 records and 17 columns. The dataset includes useful information such as app category, rating, reviews, installs, size, price, content rating, genres, last updated date, and user review sentiment.
# The main objective of this project is to analyze the data, understand user behavior, identify important trends, and generate useful insights that can help developers improve app performance and increase user satisfaction.
# ## steps involves
# 1) Data Loading-Loaded the dataset into Google Colab.Dataset shape: (122,662, 17).
# 2) Data Cleaning and Preprocessing-Removed duplicate records,Handled missing values in important columns,Converted data into the correct format for analysis.
# 3) Data Analysis and Visualization
# -Different charts were created to understand the data and find useful insights, including:
#
# Distribution of app ratings.
#
# App categories and content ratings.
#
# Free vs Paid app analysis.
#
# Relationship between reviews, ratings, installs, and app size.
# User sentiment analysis.
#  and many more
#
# The following charts were used in this project to analyze the Google Play Store data:
#
# Histogram,
# Count Plot,
# Bar Plot,
# Line Chart,
# Scatter Plot,
# Pie Chart,
# Box Plot,
# Area Chart,
# Heatmap,
# Pair Plot.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/waditakekalpana2112000-hub/Google-Play-Store-Data-EDA-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The Google Play Store has millions of apps in different categories like Games, Business, Education, Health, and Lifestyle. An app's success depends on many factors such as its category, rating, reviews, installs, price, and regular updates.
# Although there are many apps, only some become popular and receive high ratings and positive reviews. This project aims to understand the factors that help apps perform better and keep users satisfied.
#
# This project answers the following questions:
# 1.Which app categories are the most popular?
#
# 2.How do ratings and reviews affect an app's success?
#
# 3.Do free and paid apps perform differently?
#
# 4.How does user sentiment (positive, negative, or neutral) relate to app ratings and installs?
#
# 5.Do regular app updates improve ratings and user satisfaction?
#
# Using a dataset of 122,662 records and 17 columns, this project analyzes the data to find useful patterns and insights. These insights can help app developers and businesses improve their apps, increase user satisfaction, and make better business decisions.

# %% [markdown]
#  **Define Your Business Objective?**

# %% [markdown]
# The main objective of this project is to analyze Google Play Store app data and understand the factors that affect an app's success. By studying app ratings, reviews, installs, categories, price, and user sentiment, we can find useful insights for better decision-making.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the 'play store data' Dataset from the csv file
play_store_data = pd.read_csv('/content/Play Store Data.csv')

# %%
user_review_data = pd.read_csv("/content/User Reviews.csv")

# %%
#Merge the two datasets on the common column 'App'.
#Perform an inner join to keep only the rows where 'app' exists in both datasets.
Data_df = pd.merge(play_store_data,user_review_data,on='App',how='inner')
Data_df
# Out:
#                         App        Category  Rating Reviews Size  Installs  \
# 0       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# 1       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# 2       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# 3       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# 4       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# ...                     ...             ...     ...     ...  ...       ...
# 122657          FP Notebook         MEDICAL     4.5     410  60M   50,000+
# 122658          FP Notebook         MEDICAL     4.5     410  60M   50,000+
# 122659          FP Notebook         MEDICAL     4.5     410  60M   50,000+
# 122660          FP Notebook         MEDICAL     4.5     410  60M   50,000+
# 122661          FP Notebook         MEDICAL     4.5     410  60M   50,000+
#
#         Type Price Content Rating                     Genres  \
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
Data_df.head()
# Out:
#                    App        Category  Rating Reviews Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 0     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3     0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# 1       2.0.0  4.0.3 and up
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
Data_df.shape
# Out:
# (122662, 17)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122662 entries, 0 to 122661
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   App                     122662 non-null  object
#  1   Category                122662 non-null  object
#  2   Rating                  122622 non-null  float64
#  3   Reviews                 122662 non-null  object
#  4   Size                    122662 non-null  object
#  5   Installs                122662 non-null  object
#  6   Type                    122662 non-null  object
#  7   Price                   122662 non-null  object
#  8   Content Rating          122662 non-null  object
#  9   Genres                  122662 non-null  object
#  10  Last Updated            122662 non-null  object
#  11  Current Ver             122662 non-null  object
#  12  Android Ver             122662 non-null  object
#  13  Translated_Review       72605 non-null   object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(Data_df[Data_df.duplicated()])
# Out:
# 81001

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
Data_df.isnull().sum()
# Out:
# App                           0
# Category                      0
# Rating                       40
# Reviews                       0
# Size                          0
# Installs                      0
# Type                          0
# Price                         0
# Content Rating                0
# Genres                        0
# Last Updated                  0
# Current Ver                   0
# Android Ver                   0
# Translated_Review         50057
# Sentiment                 50047
# Sentiment_Polarity        50047
# Sentiment_Subjectivity    50047
# dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(Data_df.isnull(), cmap='coolwarm', cbar=False, yticklabels=False)
plt.title("missing values of heatmap",fontsize=10,color='Blue')
plt.xlabel('Columns')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After merging the Play Store and User Review datasets, I observed that the combined dataset contains 122,662 rows and 17 columns. Among these, three columns—'Rating', 'Sentiment_Polarity', and 'Sentiment_Subjectivity'—have the float64 data type, while the remaining columns are of the object data type. I also identified a total of 81,001 duplicate records in the merged dataset.And i also examined the missing values and found that they are present in the 'Rating', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity', and 'Sentiment_Subjectivity' columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
Data_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
Data_df.describe(include='all')
# Out:
#                                                       App Category  \
# count                                              122662   122662
# unique                                               1020       33
# top     CBS Sports App - Scores, News, Stats & Watch Live     GAME
# freq                                                 2560    28360
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#                Rating Reviews                Size     Installs    Type  \
# count   122622.000000  122662              122662       122662  122662
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# App : Name of the application available on the Google Play Store.
#
# Category : Category to which the application belongs (e.g.-Entertainment,Technicals,Kids,Games)
#
# Rating : Average user rating of the application on the Google Play Store.
#
# Reviews : Total number of user reviews submitted for the application.
#
# Size : Size of the application file.
#
# Installs : Total number of times the application has been installed.
#
# Type : Free or Paid.
#
# Price : Price of the application. (O For free)
#
# Content Rating : Age group for which the application is suitable.
#
# Genres : Specific genre or subcategory of the application.
#
# Last Updated : Date on which the application was last updated.
#
# Current Ver : Current version of the application available on the Google Play Store.
#
# Android Ver : Minimum Android version required to install and run the application.
#
# Translated_Review : User review translated into English for sentiment analysis.
#
# Sentiment : Overall sentiment expressed in the review (Positive, Negative, or Neutral).
#
# Sentiment_Polarity : Numerical score representing the sentiment of the review, ranging from -1 (negative) to 1 (positive).
#
# Sentiment_Subjectivity : Numerical score indicating whether the review is objective (0) or subjective (1).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
Data_df.nunique()
# Out:
# App                        1020
# Category                     33
# Rating                       23
# Reviews                    1330
# Size                        178
# Installs                     13
# Type                          2
# Price                        14
# Content Rating                5
# Genres                       73
# Last Updated                299
# Current Ver                 598
# Android Ver                  25
# Translated_Review         26682
# Sentiment                     3
# Sentiment_Polarity         5295
# Sentiment_Subjectivity     4382
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#1.creating copy of current database as new_Data_df
New_Data_df=Data_df.copy()
New_Data_df
# Out:
#                         App        Category  Rating Reviews Size  Installs  \
# 0       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# 1       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# 2       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# 3       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# 4       Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+
# ...                     ...             ...     ...     ...  ...       ...
# 122657          FP Notebook         MEDICAL     4.5     410  60M   50,000+
# 122658          FP Notebook         MEDICAL     4.5     410  60M   50,000+
# 122659          FP Notebook         MEDICAL     4.5     410  60M   50,000+
# 122660          FP Notebook         MEDICAL     4.5     410  60M   50,000+
# 122661          FP Notebook         MEDICAL     4.5     410  60M   50,000+
#
#         Type Price Content Rating                     Genres  \
# ...

# %%
#2.Finding null values
New_Data_df.isnull().sum()
# Out:
# App                           0
# Category                      0
# Rating                       40
# Reviews                       0
# Size                          0
# Installs                      0
# Type                          0
# Price                         0
# Content Rating                0
# Genres                        0
# Last Updated                  0
# Current Ver                   0
# Android Ver                   0
# Translated_Review         50057
# Sentiment                 50047
# Sentiment_Polarity        50047
# Sentiment_Subjectivity    50047
# dtype: int64

# %%
#3.converting null values into percentage.
New_Data_df.isnull().sum()/len(New_Data_df)*100
# Out:
# App                        0.000000
# Category                   0.000000
# Rating                     0.032610
# Reviews                    0.000000
# Size                       0.000000
# Installs                   0.000000
# Type                       0.000000
# Price                      0.000000
# Content Rating             0.000000
# Genres                     0.000000
# Last Updated               0.000000
# Current Ver                0.000000
# Android Ver                0.000000
# Translated_Review         40.808889
# Sentiment                 40.800737
# Sentiment_Polarity        40.800737
# Sentiment_Subjectivity    40.800737
# dtype: float64

# %%
#4.Checking the skewness of the rating column.
Skewness = New_Data_df['Rating'].skew()
Skewness #negative skew indicates left-skewed distribution
# Out:
# np.float64(-1.6538496366880835)

# %%
#5.Droping rows with missing values in review or the sentiment review column because these makes EDA process complex.
#for ensuring data quality i would like to remove incomplete records.(by using drop)
New_Data_df.dropna(
    subset=['Translated_Review', 'Sentiment', 'Sentiment_Polarity','Sentiment_Subjectivity'],inplace=True)

# %%
#6.drop duplicate rows if any
New_Data_df.drop_duplicates(inplace=True)

#7.reset index
New_Data_df.reset_index(drop=True,inplace=True)

# %%
#8.now we are checking if there is any duplicate row.
New_Data_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#9.The Installs column contains strings with '+' and ',' (for example, "500,000+").
#These non-numeric characters prevent mathematical analysis.
#We need to remove the '+' and ',' to clean the data and then convert the column into integers.
New_Data_df['Installs']=New_Data_df['Installs'].astype(str)
New_Data_df['Installs']=New_Data_df['Installs'].astype(str).str.replace(r'[+,]','',regex=True).astype(int)

# %%
#10.The reviews column which is stored in object means a string, even they represent the numbers.
#so we have to convert integer type that allows to perform  numerical operation properly.
New_Data_df['Reviews']=New_Data_df['Reviews'].astype(int)

# %%
#11.convert the price column from string to float.
New_Data_df['Price']=New_Data_df['Price'].astype(str).str.replace('$', '', regex=False).astype(float)

# %%
#12.clean and convert the Size column into float.
#Step 1: Drop unwanted rows where size is 'Varies with device' or  missing
New_Data_df= New_Data_df[New_Data_df['Size'].notna() & (New_Data_df['Size'] != 'Varies with device')].copy()
#step 2:converting remaining size values to float(MB)
def size_to_mb(size):
  size = str(size).strip()
  if 'M' in size:
    return float(size.replace('M',''))
  elif 'k' in size or 'K' in size:
    return float(size.replace('k','').replace('K','')) / 1024
  else:
    return float(size)

New_Data_df['Size'] = New_Data_df['Size'].apply(size_to_mb)
#step3:convert data type to float
New_Data_df['Size'] =New_Data_df['Size'].astype(float)

# %%
#13.Convert Last Updated data type from string to Datetime
New_Data_df['Last Updated'] = pd.to_datetime(New_Data_df['Last Updated'])

# %%
#14.Convert Sentiment columns to float
New_Data_df['Sentiment_Polarity'] = New_Data_df['Sentiment_Polarity'].astype(float)
New_Data_df['Sentiment_Subjectivity'] = New_Data_df['Sentiment_Subjectivity'].astype(float)

# %%
#15.Extract Year and month from last update
New_Data_df['Last_Updated_Year'] = New_Data_df['Last Updated'].dt.year

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I first created a copy of the original dataset. Then, I handled missing values: for the 'Rating' column, I checked the skewness. then I dropped several columns—including 'Translated_Review', 'Sentiment', 'Sentiment_Polarity', and 'Sentiment_Subjectivity'—because they had too many missing values, which can make EDA process complex. After that, I reset the index so the dataset remained continuous. Next, I performed data type conversions: I converted the 'Installs' column from a string (with non-numeric characters) to integers, the 'Review' column from string to integer, and the 'Price' column from string to float. I also converted the 'Last Updated' column from string to datetime. Finally, I converted the sentiment columns to floats and extracted both the year and month from the 'Last Updated' column.
# #insights
# 1.Missing Data: The rating column was safely filled using the median, and rows with missing sentiment data were dropped to maintain the integrity of the analysis.
#
# 2.Data Consistency: All numeric columns—including Installs, Reviews, and Price—were converted to appropriate numerical types, ensuring accurate aggregation and visualization.
#
# 3.Time Features: By extracting the year and month from the last update, I enabled trend analysis of app updates over time.
#
# 4.Bias Reduction: Duplicate rows were removed, and incomplete sentiment data was dropped, ensuring a more reliable and unbiased exploratory data analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# set the figure size
plt.figure(figsize=(8,6))

# creating a histogram with kde(kernal density estimate)plot
sns.histplot(New_Data_df['Rating'], bins=24, kde=True, color='blue')

# add title and axis lable
plt.title("Distribution of App Ratings",color='red',fontsize=16, weight='bold')
plt.xlabel("App Rating",color='red',fontsize=12)
plt.ylabel("Frequency",color='red',fontsize=12)

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose the histogram because it shows app rating ditribution that helps to find the rating pattern and central tendoncy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Most apps have high ratings, with the majority of ratings falling between 4.0 and 4.6
#
# 2.The highest concentration of apps is around 4.4–4.5, indicating that most apps receive positive user feedback.
#
# 3.The distribution is negatively (left) skewed, as the tail extends toward lower ratings while most observations are concentrated at higher ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can contribute to a positive business impact because the majority of apps in the dataset have ratings above 4.0, indicating good user satisfaction and a positive user experience. Higher-rated apps are more likely to gain user trust, attract more downloads, and improve their visibility on the Google Play Store.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# set the figure size
plt.figure(figsize=(15,6))

# Plot histogram for app size(MB)
plt.hist(New_Data_df['Size'], bins=45, color='purple',edgecolor='black')

# add title and axis lable
plt.title("Distribution of app size(MB)",color='blue',fontsize=16)
plt.xlabel("App size",color='blue',fontsize=12, weight='bold')
plt.ylabel("Number of app",color='blue',fontsize=12)

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a histogram because it is the best chart to show the distribution of a continuous variable like app size. It helps us understand how app sizes are distributed and identify the most common app size range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Most apps have small to medium file sizes.
#
# 2.Only a few apps have very large file sizes.
#
# 3.This shows that developers prefer to build apps with smaller sizes so they are easier to download and use.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can create a positive business impact because smaller apps are easier to download, use less storage, and attract more users. However, very large apps may receive fewer downloads because they require more storage space and internet data. Therefore, developers should optimize app size to improve the user experience and increase downloads.

# %% [markdown]
# #### Chart - 3

# %%
from matplotlib.lines import lineStyles
# Chart - 3 visualization code
# set the figure size
plt.figure(figsize=(6,6))

# Count number of apps updated each year
updates_per_year = New_Data_df['Last_Updated_Year'].value_counts().sort_index()

# Plot line chart
plt.plot(updates_per_year.index,updates_per_year.values,linestyle='--',marker='o',color='blue')

# add title and axis label
plt.title("Trend of App Updates by Year",color='black',fontsize=16, weight='bold')
plt.xlabel("Year",color='black',fontsize=12)
plt.ylabel("Number of Apps Updated",color='black',fontsize=12)

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a line chart because it is the best chart to show changes over the years.It is easy to understand whether app updates are increasing or decreasing with time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.The number of app updates increased steadily over the years, showing that developers became more active.
#
# 2.The highest number of updates was observed in the later years from 2016 to 2018.
#
# 3.Overall, the chart indicates that app maintenance became more important over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact because regular app updates improve app quality, user satisfaction, and trust. This can increase downloads and user retention. However, apps that are not updated regularly may become outdated, contain more bugs, and lose users, which can lead to negative growth.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# set the figure size
plt.figure(figsize=(8,6))

# Count apps by Content Rating
content_counts = New_Data_df['Content Rating'].value_counts()

# Create the bar chart
content_counts.plot(kind='bar', color='blue', edgecolor='black')

# add title and lable axis
plt.title("Apps Distribution by Content Rating",color='red', fontsize=14)
plt.xlabel("Content Rating",color='red', fontsize=12)
plt.ylabel("Number of Apps",color='red', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle="--", alpha=0.7)

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose the bar chart because it is most effective to compare different app categories. It helps visualize the number of apps in each content rating category and makes comparisons simple and clear.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.The 'Everyone' content rating has the highest number of apps, showing that most apps are designed for users of all age groups.
#
# 2.The 'Teen' and 'Everyone 10+' categories also contain a considerable number of apps, indicating strong demand from younger users.
#
# 3.Categories such as 'Mature 17+' and 'Adults Only 18+' have fewer apps, showing that most developers create apps for all age groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can create a positive business impact because most apps are rated 'Everyone', which means they can reach more users. Developers can create apps for all age groups to increase downloads and user engagement. However, categories like 'Mature 17+' and 'Adults Only 18+' have fewer apps because they are meant for a limited audience. As a result, these apps may get fewer downloads and slower growth. Businesses should choose the right content rating based on their target users.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# set the figure size
plt.figure(figsize=(12,8))

# Count the number of apps in each category
category_counts = New_Data_df['Category'].value_counts()

# Create the bar chart
sns.barplot(x=category_counts.index,y=category_counts.values,color='red')

# add title and lable axis
plt.title("Distribution Of Apps Across Categories",fontsize=16,color = 'blue',weight='bold')
plt.xlabel("App Categories",color = 'blue',fontsize=12)
plt.ylabel("Number of Apps",color = 'blue',fontsize=12)
plt.xticks(rotation=75)

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose the bar chart because it is most effective to compare different app categories. It clearly highlights which category have highest number of apps or which have lowest number of apps,It make the distribution easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Games dominate the Play Store: This suggests a strong user demand for entertainment apps.
#
# 2.Lifestyle-related apps are also significant: Categories like Family, Health & Fitness, Travel, and Tools are also highly developed. This shows that user needs span beyond entertainment and into daily life, meaning businesses can tap into these areas for growth.
#
# 3.Niche categories have fewer apps: Categories like Comics, Events, and Maps & Navigation have low app counts. This suggests either limited user engagement or less developer focus.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes,the gaine insights can help create a positive business impact because they show where user demand is strongest—like in the Games and Lifestyle categories. This means developers can focus on these areas, boosting downloads and engagement.But, some niche categories—like Comics or Events—have fewer apps, and that could slow growth. If businesses put too much focus on these without doing enough market research, it might lead to negative growth. So, it’s important to balance all the things.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Remove extreme outliers in Reviews
df_plot = New_Data_df[New_Data_df['Reviews'] < 500000].copy()

# set the figure size
plt.figure(figsize=(12,6))

# Scatter plot
sns.scatterplot(x='Size',y='Reviews',data=df_plot,alpha=0.5,color='blue',s=150)

# add title and axis label
plt.title("Relationship between App Size and Number of Reviews",fontsize=14,weight='bold',color='navy')
plt.xlabel("App Size (MB)",color='navy')
plt.ylabel("Number of Reviews",color='navy')

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a scatter plot because it is the best chart to show the relationship between two numerical variables. It helps us understand whether app size affects the number of reviews and identify any patterns or outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.There is no strong relationship between app size and the number of reviews.
#
# 2.Some apps receive a very high number of reviews regardless of their size.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact because they show that app size alone does not decide the number of reviews. Businesses should focus on improving app quality, features, and user experience to attract more users.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# set the figure size
plt.figure(figsize=(8,6))

# Count Plot
sns.countplot(x='Type',data=New_Data_df,palette=['pink', 'red'])

# add title and axis label
plt.title("Number of Apps by Type (Free vs Paid)", fontsize=14, weight='bold', color='blue')
plt.xlabel("App Type",color='blue',fontsize=12)
plt.ylabel("Number of Apps",color='blue',fontsize=12)
plt.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a count plot because it is the best chart to compare the number of apps in different categories. It clearly shows how many apps are Free and how many are Paid, making the comparison simple and easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.The chart shows that Free apps are much more than Paid apps on the Google Play Store.
#
# 2.Only a small number of apps are Paid.
#
# 3.This means most developers prefer offering free apps to attract more users and downloads.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help businesses decide the right pricing strategy. Since most users prefer free apps, developers can launch free apps or use in-app purchases and ads to earn revenue.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# get top 10 categories by number of apps
top_10_categories = New_Data_df['Category'].value_counts().head(10)

# set the figure size
plt.figure(figsize=(10,5))

# pie chart
plt.pie(top_10_categories,labels=top_10_categories.index,autopct='%1.1f%%',startangle=150,colors = plt.cm.tab10.colors)

# add title
plt.title('Top 10 categories by number of apps',color='red',fontsize=14)

# show thw plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose pie chart because it shows proportion of each app related to category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Games lead the top categories, representing 40.2%, making it the largest segment.
#
# 2.Significant Others: Family apps (13.6%) and Health & Fitness (7.3%) also hold notable shares.
#
# 3.Market Insight: Other categories (Tools, Productivity, Sports, etc.) contribute 5 to 7%, indicating a smaller but diverse presence.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight can help the business by focusing on popular categories like Games, Family, and Health & Fitness, which have a large number of users and lots of engagement. At the same time, smaller categories give chances to stand out with less competition, letting new ideas grow. But, because most of the market is in a few categories, it also means there’s strong competition, and smaller categories might grow more slowly.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# count review by sentiment
sentiment_count = New_Data_df['Sentiment'].value_counts()

# set the figure size
plt.figure(figsize=(10,5))

# pie chart
plt.pie(sentiment_count,labels=sentiment_count.index,autopct='%1.1f%%',startangle=150,colors = plt.cm.tab10.colors)

# add title
plt.title('review by sentiment',color='red',fontsize=14)

# show thw plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a pie chart because it shows the proportion of app reviews in each sentiment category—positive, negative, and neutral. Pie charts make it easy to see which sentiment is biggest at a glance, so you can quickly understand the overall pattern, especially when you just want to compare parts of a whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Most people, 63.6%, gave positive reviews, which means they really like the app.
#
# 2.23.9% gave negative reviews, which shows there are some things that need to get better.
#
# 3.12.5%, gave neutral reviews, meaning they don’t have strong feelings either way.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight can help the business grow. Since most reviews are positive, the company can use this to attract new users and keep them. By seeing what people like, the business can improve features and make the app even better, which keeps users coming back.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# set the figure size
plt.figure(figsize=(10,4))

# Boxplot for Price vs App Type
sns.boxplot(x='Type', y='Price', data=New_Data_df, color='skyblue')

# add title and axis labels
plt.title("Price Distribution by App Type",color='black',fontsize=13, weight='bold')
plt.xlabel("App Type",color='black',fontsize=12)
plt.ylabel("Price ($)",color='black',fontsize=12)

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a box plot because it is the best chart to compare the price distribution of Free and Paid apps. It clearly shows the median, spread of the data, and any outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.All Free apps have a price of $0, while Paid apps have different price ranges.
#
# 2.Most Paid apps are priced between approximately 2 and 10$.
#
# 3.There is one Paid app with a very high price (around $30), which appears as an outlier.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact because they show the common price of Paid apps. Businesses can set a reasonable price to attract more users and increase downloads. However, apps with very high prices may get fewer downloads because most users prefer free or low-priced apps.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# set the figure size
plt.figure(figsize=(10,4))

# Boxplot for Rating vs App Type
sns.boxplot(x='Type', y='Rating', data=New_Data_df, color='Blue')

# add title and axis labels
plt.title("Rating Distribution by App Type",color='red',fontsize=14, weight='bold')
plt.xlabel("App Type",color='red')
plt.ylabel("Rating",color='red')

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a box plot because it is the best chart to compare the ratings of Free and Paid apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Both Free and Paid apps have high ratings, mostly between 4.2 and 4.5.
#
# 2.Paid apps have more consistent ratings with fewer outliers.
#
# 3.Overall, both app types receive good user ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact because they show that both Free and Paid apps have good ratings, which can increase user trust and downloads. However, some Free apps have very low ratings, which may reduce user satisfaction and lead to fewer downloads.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Group by year and sentiment, then count reviews
review_count = New_Data_df.groupby(['Last_Updated_Year', 'Sentiment'])['Translated_Review'].count().reset_index(name='Review Count')

# Set up the figure size
plt.figure(figsize=(10, 6))

# Create the bar plot
sns.barplot(data=review_count,x='Last_Updated_Year',y='Review Count',hue='Sentiment',palette='Set2')

# Add title and axis labels
plt.title('Count of Reviews by Sentiment for Each Year', fontsize=14, weight='bold', color='blue')
plt.xlabel('Year', color='blue', fontsize=12)
plt.ylabel('Number of Reviews', color='blue', fontsize=12)
plt.legend(title='Sentiment')
plt.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart because it clearly shows how many reviews there are for each year and each sentiment. Bar charts are great for comparing different groups and seeing which sentiment is bigger in each year, so it’s easy to spot patterns over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Positive reviews stayed the highest from 2015 to 2018, showing most users were happy.
#
# 2.Between 2016 and 2018, positive reviews grew a lot, especially in 2018, meaning more engagement.
#
# 3,Before 2016, reviews were lower, but by 2017, they started going up, and the general sentiment stayed steady despite these changes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this can create a positive business impact. The steady positive reviews show that users are happy, which can improve the app’s reputation and help with marketing. The big jump in positive reviews in 2018 shows that recent updates worked well, and the slow growth in 2017 means more people started using it. Keeping the same balance in sentiment helps focus on improving quality and dealing with any negative feedback, which can boost ratings and bring in more users.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Group by year and calculate average sentiment polarity
polarity_trend = New_Data_df.groupby('Last_Updated_Year')['Sentiment_Polarity'].mean().reset_index()

# Set up the figure size
plt.figure(figsize=(10, 6))

# Plot the line chart
plt.plot(polarity_trend['Last_Updated_Year'],polarity_trend['Sentiment_Polarity'],marker='o',linestyle='-',color='blue')

# Add title and axis labels
plt.title('Average Sentiment Polarity of Reviews by Year',fontsize=12,color='red')
plt.xlabel('Year',fontsize=14,color='Red')
plt.ylabel('Average Sentiment Polarity',fontsize=12,color='red')
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a line chart because it’s ideal for showing trends over time. It clearly displays how sentiment changes each year, making it easy to see if user feelings go up, down, or stay steady, so we can understand the pattern by year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Sharp Drop (2011-2012): The average sentiment fell a lot, meaning more negative reviews or fewer positive ones.
#
# 2.Recovery (2012-2015): Sentiment slowly improved, with ups and downs, showing that users were becoming more satisfied again.
#
# 3.Peak in 2015: Sentiment reached its highest point, meaning the most positive reviews in that time.
#
# 4.Decline (2015-2017): Sentiment dropped again, showing fewer positive reviews.and
# Small Recovery (2017-2018): Sentiment went up a bit again but didn’t reach the top level.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight can help the business because it shows when users were most positive, so the company can repeat the successful updates from those years. The small rise in 2017 to 2018 shows a chance to keep improving the app. But the drops in 2011-2012 and 2015-2017 show times when users were less happy, which could lower engagement or revenue. By spotting and fixing problems in those years, the app can avoid losing growth.

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code
# Group by year and sentiment, then count reviews
sentiment_year = New_Data_df.groupby(['Last_Updated_Year', 'Sentiment']).size().unstack(fill_value=0)

# Set up the figure size
plt.figure(figsize=(10, 6))

# Plot stacked area chart
sentiment_year.plot(kind='area',alpha=0.8,color=['red','blue','green'])

## Add title and axis labels
plt.title('Sentiment Distribution of App Reviews Over Year', fontsize=14, color='red')
plt.xlabel('Year', color='red', fontsize=12)
plt.ylabel('Number of Reviews', color='red', fontsize=12)
plt.legend(title='Sentiment')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a stacked area chart because it shows how positive, negative, and neutral reviews change over time. It lets us compare all the sentiments in one chart and clearly shows trends by year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.We see a growth in total reviews from 2017 to 2018, meaning more people left feedback.
#
# 2.Positive sentiment stayed the largest share and grew the most, showing that most users were happy.
#
# 3.Both negative and neutral reviews also went up in recent years, especially after 2016, meaning more mixed opinions appeared. This overall helps us see how user feelings shifted across the years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight can create a positive business impact.By seeing the rise in negative and neutral reviews, the company can find and fix common problems, improving the app. And the growth in positive reviews shows that users are happy, so the business can use that in marketing to build trust. Overall by tracking sentiment over time, the company can see if updates are helping or hurting, guiding better future decisions.

# %% [markdown]
# #### Chart - 15

# %%
# Chart - 15 visualization code
# Set up the figure size
plt.figure(figsize=(10,6))

#scatter plot
sns.scatterplot(data=New_Data_df,x='Reviews',y='Rating',alpha=0.6,color='purple')

# Add title and axis labels
plt.title("Relationship between Reviews and Rating", fontsize=14, weight='bold', color='black')
plt.xlabel("Reviews", fontsize=12, color='black')
plt.ylabel("Rating", fontsize=12, color='black')
plt.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a scatter plot because it clearly shows the relationship between the number of reviews and app ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Most apps have a small number of reviews but maintain good ratings.
#
# 2.Apps with a large number of reviews generally have ratings between 4.0 and 4.8
#
# 3.There is no strong relationship between the number of reviews and app ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact.
# Businesses should focus on improving app quality to achieve higher ratings.
# Encouraging more user reviews can increase app visibility and credibility.
# Monitoring reviews and ratings helps businesses improve user satisfaction and make better decisions.

# %% [markdown]
# #### Chart - 16

# %%
# Chart - 16 visualization code
# Calculate average rating by app type
avg_rating = New_Data_df.groupby('Type')['Rating'].mean().reset_index()

# Set figure size
plt.figure(figsize=(4,4))

# Bar plot
sns.barplot(data=avg_rating,x='Type',y='Rating',palette=['pink', 'red'])

# add Title and axis labels
plt.title("Average Rating by App Type", fontsize=14, weight='bold', color='blue')
plt.xlabel("App Type", fontsize=12, color='blue')
plt.ylabel("Average Rating", fontsize=12, color='blue')
plt.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar chart because it clearly compares the average ratings of free and paid apps. It makes it easy to see the difference between the two app types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Both free and paid apps have high average ratings.
#
# 2.Paid apps have a slightly higher average rating than free apps.
#
# 3This shows that both app types can provide a good user experience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact.
# Businesses should focus on improving app quality to maintain high ratings.
# Good ratings can increase user trust and encourage more downloads.
# Both free and paid apps have the potential to succeed if they provide a good user experience.

# %% [markdown]
# #### Chart - 17 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Filter only numeric columns (integers and floats)
numeric_data = New_Data_df.select_dtypes(include=['int64', 'float64'])

# Calculate the correlation matrix
correlation = numeric_data.corr()

# Set up the figure size
plt.figure(figsize=(10, 8))

# Plot heatmap
sns.heatmap(correlation, annot=True, cmap='rainbow', center=0)
plt.tight_layout()

# Add a title
plt.title('Correlation Heatmap of Numeric Features',fontsize=14,color='green')

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a heatmap because it clearly shows how the numbers relate to each other. It makes it easy to spot patterns and see which features are connected quickly and clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Growth Factors: Reviews, installs, and size are strongly linked, meaning bigger apps tend to get more installs and reviews.
#
# 2.Sentiment Link: Positive and negative sentiment are connected, so more emotional reviews often have stronger opinions.
#
# 3.Price Independence: Price doesn’t strongly affect ratings, installs, or reviews, so it’s not a big driver of behavior.
#
# 4.Rating Influence: Ratings have only a small connection to installs and reviews, meaning other factors beyond popularity affect ratings.

# %% [markdown]
# #### Chart - 18 - Pair Plot

# %%
# Pair Plot visualization code
key_cols = ['Rating', 'Reviews', 'Installs', 'Price', 'Sentiment_Polarity']
df_key = New_Data_df[key_cols].dropna()

# Pair plot
sns.pairplot(df_key,kind='kde',diag_kind='kde',plot_kws={'alpha': 0.5, 's': 40, 'edgecolor': 'k'})

# Add a title
plt.suptitle('Pairwise Relationships (Key Features)', fontsize=14, weight='bold')
plt.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a pair plot because it shows the relationship between multiple numerical features in one chart. It helps compare different variables and identify patterns, trends, and possible correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Apps with more reviews generally have more installs.
#
# 2.Most apps have high ratings (around 4–5), regardless of price.
#
# 3.Price shows a weak relationship with the other variables, while reviews and installs are more closely related.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1.Focus on Popular Categories
# -Invest more in popular categories like Games, Family, and Lifestyle because they attract more users and downloads.
#
# 2.Improve User Experience-
# Pay attention to user reviews and fix common problems quickly to increase user satisfaction.
#
# 3.Choose the Right Pricing Model-
# Since most users prefer free apps, businesses can use free apps with ads or in-app purchases to increase revenue.
#
# 4.Update Apps Regularly-
# Regular updates and bug fixes help improve app performance, keep users happy, and encourage more downloads.
#
# 5.Reach More Users-
# Build apps that are suitable for a wider audience whenever possible to increase installs and grow the user base.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project analyzed Google Play Store data to identify the factors that affect app success. Through data cleaning, visualization, and sentiment analysis, we identified important patterns related to ratings, reviews, installs, app categories, and user feedback. These insights can help developers improve app quality, increase user satisfaction, and make better business decisions. By regularly updating apps and responding to user feedback, developers can increase user satisfaction, attract more downloads, and improve overall app performance.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
